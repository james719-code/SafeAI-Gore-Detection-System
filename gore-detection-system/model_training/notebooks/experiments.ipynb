# %% [markdown]
# # Gore Detection Experiments\n
# Use this notebook for quick experiments before moving stable logic into scripts.

# %%
from pathlib import Path\n
project_root = Path.cwd().resolve().parents[1]\n
project_root
